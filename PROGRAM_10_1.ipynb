# %% [markdown]
# <a href="https://colab.research.google.com/github/Alfasmoideen/Datascience/blob/main/PROGRAM_10_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
data = {'Name':['Tom', 'nick', 'krish', 'jack'],'Age':[20, 21, 19, 18]}
df = pd.DataFrame(data)
print(df)
data = {'Name':['Jai', 'Princi', 'Gaurav', 'Anuj'],
'Age':[27, 24, 22, 32],
'Address':['Delhi', 'Kanpur', 'Allahabad', 'Kannauj'],
'Qualification':['Msc', 'MA', 'MCA', 'Phd']}
df = pd.DataFrame(data)
print(df[['Name', 'Qualification']])
# Out:
#     Name  Age
# 0    Tom   20
# 1   nick   21
# 2  krish   19
# 3   jack   18
#      Name Qualification
# 0     Jai           Msc
# 1  Princi            MA
# 2  Gaurav           MCA
# 3    Anuj           Phd

# %%
data = pd.read_csv("/content/empl.csv")
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   NO             5 non-null      int64
#  1   EMPLOYEE_ID    5 non-null      int64
#  2   NAME           5 non-null      object
#  3   EMAIL          5 non-null      object
#  4   PHONE_NUMBER   5 non-null      object
#  5   HIRE_DATE      5 non-null      object
#  6   DESIGNATION    5 non-null      object
#  7   SALARY         5 non-null      int64
#  8   MANAGER_ID     5 non-null      int64
#  9   DEPARTMENT_ID  5 non-null      int64
# dtypes: int64(5), object(5)
# memory usage: 532.0+ bytes

# %%
data.head()
# Out:
#    NO  EMPLOYEE_ID    NAME     EMAIL  PHONE_NUMBER   HIRE_DATE DESIGNATION  \
# 0   0          198  Donald  DOCONNEL  650.507.9833   21-Jun-07   SH_CLERK
# 1   1          200   onald   DOCONNE  650.507.9834   21-Jun-08   SH_CLERK
# 2   2          201    nald        do  650.507.9835   21-Jun-09     AD_ASST
# 3   3          197     ald      doco  650.507.9836   21-Jun-10      MK_MAN
# 4   4          202      ld    doconn  650.507.9837   21-Jun-11      MK_REP
#
#    SALARY  MANAGER_ID  DEPARTMENT_ID
# 0   12600         124             50
# 1   12600         124             50
# 2   12600         101             10
# 3   12600         100             20
# 4   12600         201             20

# %%
first = data.head()
print(first)
# Out:
#    NO  EMPLOYEE_ID    NAME     EMAIL  PHONE_NUMBER   HIRE_DATE DESIGNATION  \
# 0   0          198  Donald  DOCONNEL  650.507.9833   21-Jun-07   SH_CLERK
# 1   1          200   onald   DOCONNE  650.507.9834   21-Jun-08   SH_CLERK
# 2   2          201    nald        do  650.507.9835   21-Jun-09     AD_ASST
# 3   3          197     ald      doco  650.507.9836   21-Jun-10      MK_MAN
# 4   4          202      ld    doconn  650.507.9837   21-Jun-11      MK_REP
#
#    SALARY  MANAGER_ID  DEPARTMENT_ID
# 0   12600         124             50
# 1   12600         124             50
# 2   12600         101             10
# 3   12600         100             20
# 4   12600         201             20

# %%
import pandas as pd
import numpy as np
arr=np.array([10,15,18,22])
s = pd.Series(arr)
print(s)
# Out:
# 0    10
# 1    15
# 2    18
# 3    22
# dtype: int64

# %%
arr=np.array(['a','b','c','d'])
s=pd.Series(arr, index=['first','second','third','fourth'])
print(s)
# Out:
# first     a
# second    b
# third     c
# fourth    d
# dtype: object

# %%
s=pd.Series(50, index=[0, 1, 2, 3, 4])
print (s)
# Out:
# 0    50
# 1    50
# 2    50
# 3    50
# 4    50
# dtype: int64

# %%
d={'Name': 'Deepthi', 'Class' : 'MCA', 'year' : 2014}
s=pd.Series(d)
print(s)
# Out:
# Name     Deepthi
# Class        MCA
# year        2014
# dtype: object

# %%
s = pd.Series([10,15,18,22])
df=pd.DataFrame(s)
df.columns=['List1']

df['List2']=20

df['List3']=df['List1']+df['List2']

print(df)
# Out:
#    List1  List2  List3
# 0     10     20     30
# 1     15     20     35
# 2     18     20     38
# 3     22     20     42

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(0)
values = np.random.randn(100)
s = pd.Series(values) # generate a pandas series
print("series\n",s)
s.plot(kind='hist', title='Normally distributed random values')
plt.show()
# Out:
# series
#  0     1.764052
# 1     0.400157
# 2     0.978738
# 3     2.240893
# 4     1.867558
#         ...
# 95    0.706573
# 96    0.010500
# 97    1.785870
# 98    0.126912
# 99    0.401989
# Length: 100, dtype: float64

# %%
s.describe()
# Out:
# count    100.000000
# mean       0.059808
# std        1.012960
# min       -2.552990
# 25%       -0.643857
# 50%        0.094096
# 75%        0.737077
# max        2.269755
# dtype: float64

# %%
df = pd.DataFrame({'A': [1, 2, 1, 4, 3],
'B': [12, 14, 11, 16, 18],
'C': ['a', 'a', 'b', 'a', 'b']})
df
# Out:
#    A   B  C
# 0  1  12  a
# 1  2  14  a
# 2  1  11  b
# 3  4  16  a
# 4  3  18  b

# %%
df.describe()
# Out:
#              A          B
# count  5.00000   5.000000
# mean   2.20000  14.200000
# std    1.30384   2.863564
# min    1.00000  11.000000
# 25%    1.00000  12.000000
# 50%    2.00000  14.000000
# 75%    3.00000  16.000000
# max    4.00000  18.000000

# %%
import pandas
iris = pandas.read_csv('/content/sample_data/california_housing_test.csv')
print(iris)
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
import pandas as pd
iris = pd.read_csv('/content/sample_data/california_housing_test.csv')
print(iris.head())
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
import pandas as pd
df = pd.DataFrame(pd.read_csv("/content/sample_data/california_housing_test.csv"))

df.hist()
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
iris['housing_median_age'].hist()
# Out:
# <Axes: >
